# %%
import os 
from dotenv import load_dotenv

load_dotenv()

os.chdir("..")

# %%
from CensusForge import CensusAPI
from fsdc_security import SecurityViz
import polars as pl

sv = SecurityViz()

capi = CensusAPI(os.environ.get("CENSUS_TOKEN"))

# %%
sv.gen_graph_house(2024)

# %%
sv.gen_graph_total(2024)
